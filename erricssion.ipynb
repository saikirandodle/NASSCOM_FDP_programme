# %% [markdown]
# <a href="https://colab.research.google.com/github/saikirandodle/NASSCOM_FDP_programme/blob/main/erricssion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset (place the CSV in the same folder as this notebook)
df = pd.read_csv('/content/ericsson_patent_rich_dataset.csv')

# %%
# Print the number of rows and columns in a DataFrame.
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (30118, 55)

# %%
# View sample records
display(df.head())
# Out:
#   patent_id patent_type patent_date  \
# 0   3934093     utility  1976-01-20
# 1   3936612     utility  1976-02-03
# 2   3936781     utility  1976-02-03
# 3   3938025     utility  1976-02-10
# 4   3938040     utility  1976-02-10
#
#                                                                                                             patent_title  \
# 0                                                          Transit exchange for asynchronous data with unknown structure
# 1                                                                         Control and holding circuit for relay matrices
# 2                                                                                 Selecting device for crossbar switches
# 3                                DC to DC converter for producing two individually controlled and stabilized DC-voltages
# 4  Apparatus for measuring a signal voltage including a current source with a control input on which said signal appears
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30118 entries, 0 to 30117
# Data columns (total 55 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   patent_id                         30118 non-null  object
#  1   patent_type                       30118 non-null  object
#  2   patent_date                       30118 non-null  object
#  3   patent_title                      30118 non-null  object
#  4   year                              30118 non-null  int64
#  5   quarter                           30118 non-null  int64
#  6   month                             30118 non-null  int64
#  7   day_of_week                       30118 non-null  int64
#  8   day_of_year                       30118 non-null  int64
#  9   quarter_end                       30118 non-null  object
#  10  title_len_chars                   30118 non-null  int64
# ...
